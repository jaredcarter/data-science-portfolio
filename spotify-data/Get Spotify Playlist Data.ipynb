# %%
# Thank you to https://stmorse.github.io/journal/spotify-api.html for getting started
import pandas as pd # csv and dataframes
import requests # Spotify API
import config_secrets # Retrieve my secrets from this file

# Secrets from developer.spotify.com account
# You would have to change this
CLIENT_ID = config_secrets.CLIENT_ID
CLIENT_SECRET = config_secrets.CLIENT_SECRET

# How to get a token
AUTH_URL = 'https://accounts.spotify.com/api/token'

# Where to send spotify GET requests
BASE_URL = 'https://api.spotify.com/v1/'

# %%
# POST to get our access token
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET
})

auth_response_data = auth_response.json()
access_token = auth_response_data['access_token']

# Include this in every GET request to make sure we have access
headers = {'Authorization': f"Bearer {access_token}"}

# %%
### CHANGE THIS ###############
playlist_name = "This Is Raffi"
playlist_id = '37i9dQZF1DZ06evO4nGfER'
###############################
r_playlist = requests.get(BASE_URL + f"playlists/{playlist_id}/tracks", headers=headers)
df_playlist = pd.json_normalize(r_playlist.json()['items'])
df_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 40 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   added_at                            46 non-null     object
#  1   is_local                            46 non-null     bool
#  2   primary_color                       0 non-null      object
#  3   added_by.external_urls.spotify      46 non-null     object
#  4   added_by.href                       46 non-null     object
#  5   added_by.id                         46 non-null     object
#  6   added_by.type                       46 non-null     object
#  7   added_by.uri                        46 non-null     object
#  8   track.album.album_type              46 non-null     object
#  9   track.album.artists                 46 non-null     object
#  10  track.album.available_markets       46 non-null     object
#  11  track.album.external_urls.spotify   46 non-null     object
#  12  track.album.href                    46 non-null     object
#  13  track.album.id                      46 non-null     object
#  14  track.album.images                  46 non-null     object
#  15  track.album.name                    46 non-null     object
#  16  track.album.release_date            46 non-null     object
#  17  track.album.release_date_precision  46 non-null     object
#  18  track.album.total_tracks            46 non-null     int64
#  19  track.album.type                    46 non-null     object
#  20  track.album.uri                     46 non-null     object
#  21  track.artists                       46 non-null     object
#  22  track.available_markets             46 non-null     object
#  23  track.disc_number                   46 non-null     int64
#  24  track.duration_ms                   46 non-null     int64
#  25  track.episode                       46 non-null     bool
#  26  track.explicit                      46 non-null     bool
#  27  track.external_ids.isrc             46 non-null     object
#  28  track.external_urls.spotify         46 non-null     object
#  29  track.href                          46 non-null     object
#  30  track.id                            46 non-null     object
#  31  track.is_local                      46 non-null     bool
#  32  track.name                          46 non-null     object
#  33  track.popularity                    46 non-null     int64
#  34  track.preview_url                   0 non-null      object
#  35  track.track                         46 non-null     bool
#  36  track.track_number                  46 non-null     int64
#  37  track.type                          46 non-null     object
#  38  track.uri                           46 non-null     object
#  39  video_thumbnail.url                 0 non-null      object
# dtypes: bool(5), int64(5), object(30)
# memory usage: 12.9+ KB

# %%
# Get audio features described at the link below (up to 100 songs at a time)
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features
r_features = requests.get(BASE_URL + 'audio-features?ids=' + ','.join(df_playlist['track.id']), headers=headers)
df_features = pd.json_normalize(r_features.json()['audio_features'])
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      46 non-null     float64
#  1   energy            46 non-null     float64
#  2   key               46 non-null     int64
#  3   loudness          46 non-null     float64
#  4   mode              46 non-null     int64
#  5   speechiness       46 non-null     float64
#  6   acousticness      46 non-null     float64
#  7   instrumentalness  46 non-null     float64
#  8   liveness          46 non-null     float64
#  9   valence           46 non-null     float64
#  10  tempo             46 non-null     float64
#  11  type              46 non-null     object
#  12  id                46 non-null     object
#  13  uri               46 non-null     object
#  14  track_href        46 non-null     object
#  15  analysis_url      46 non-null     object
#  16  duration_ms       46 non-null     int64
#  17  time_signature    46 non-null     int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 6.6+ KB

# %%
# Join the original table with the data we got from the Spotify API
data = df_playlist.join(df_features.set_index('id'), on='track.id', how='inner')
data.info() # Look at those columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 45
# Data columns (total 57 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   added_at                            46 non-null     object
#  1   is_local                            46 non-null     bool
#  2   primary_color                       0 non-null      object
#  3   added_by.external_urls.spotify      46 non-null     object
#  4   added_by.href                       46 non-null     object
#  5   added_by.id                         46 non-null     object
#  6   added_by.type                       46 non-null     object
#  7   added_by.uri                        46 non-null     object
#  8   track.album.album_type              46 non-null     object
#  9   track.album.artists                 46 non-null     object
#  10  track.album.available_markets       46 non-null     object
#  11  track.album.external_urls.spotify   46 non-null     object
#  12  track.album.href                    46 non-null     object
#  13  track.album.id                      46 non-null     object
#  14  track.album.images                  46 non-null     object
#  15  track.album.name                    46 non-null     object
#  16  track.album.release_date            46 non-null     object
#  17  track.album.release_date_precision  46 non-null     object
#  18  track.album.total_tracks            46 non-null     int64
#  19  track.album.type                    46 non-null     object
#  20  track.album.uri                     46 non-null     object
#  21  track.artists                       46 non-null     object
#  22  track.available_markets             46 non-null     object
#  23  track.disc_number                   46 non-null     int64
#  24  track.duration_ms                   46 non-null     int64
#  25  track.episode                       46 non-null     bool
#  26  track.explicit                      46 non-null     bool
#  27  track.external_ids.isrc             46 non-null     object
#  28  track.external_urls.spotify         46 non-null     object
#  29  track.href                          46 non-null     object
#  30  track.id                            46 non-null     object
#  31  track.is_local                      46 non-null     bool
#  32  track.name                          46 non-null     object
#  33  track.popularity                    46 non-null     int64
#  34  track.preview_url                   0 non-null      object
#  35  track.track                         46 non-null     bool
#  36  track.track_number                  46 non-null     int64
#  37  track.type                          46 non-null     object
#  38  track.uri                           46 non-null     object
#  39  video_thumbnail.url                 0 non-null      object
#  40  danceability                        46 non-null     float64
#  41  energy                              46 non-null     float64
#  42  key                                 46 non-null     int64
#  43  loudness                            46 non-null     float64
#  44  mode                                46 non-null     int64
#  45  speechiness                         46 non-null     float64
#  46  acousticness                        46 non-null     float64
#  47  instrumentalness                    46 non-null     float64
#  48  liveness                            46 non-null     float64
#  49  valence                             46 non-null     float64
#  50  tempo                               46 non-null     float64
#  51  type                                46 non-null     object
#  52  uri                                 46 non-null     object
#  53  track_href                          46 non-null     object
#  54  analysis_url                        46 non-null     object
#  55  duration_ms                         46 non-null     int64
#  56  time_signature                      46 non-null     int64
# dtypes: bool(5), float64(9), int64(9), object(34)
# memory usage: 19.3+ KB

# %%
data.head() # Look at the first few rows of data
# Out:
#                added_at  is_local primary_color  \
# 0  2023-09-10T11:18:03Z     False          None
# 1  2023-09-10T11:18:03Z     False          None
# 2  2023-09-10T11:18:03Z     False          None
# 3  2023-09-10T11:18:03Z     False          None
# 4  2023-09-10T11:18:03Z     False          None
#
#    added_by.external_urls.spotify                      added_by.href  \
# 0  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 1  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 2  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 3  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 4  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
#
#   added_by.id added_by.type   added_by.uri track.album.album_type  \
# 0                      user  spotify:user:                  album
# 1                      user  spotify:user:                  album
# 2                      user  spotify:user:                  album
# 3                      user  spotify:user:                  album
# 4                      user  spotify:user:                  album
#
#                                  track.album.artists  ... instrumentalness  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...         0.000000
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...         0.000002
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...         0.043100
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...         0.000000
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...         0.000000
#
#   liveness valence    tempo            type  \
# 0   0.3460   0.671  185.302  audio_features
# 1   0.4520   0.571  137.520  audio_features
# 2   0.1670   0.484   97.764  audio_features
# 3   0.1020   0.869  204.418  audio_features
# 4   0.0875   0.792  128.483  audio_features
#
#                                     uri  \
# 0  spotify:track:0e1mUAXE8jSG9ExAS4AWU7
# 1  spotify:track:7zQFM7bHcyMh4QQFdBkjrE
# 2  spotify:track:2Qu65QrO1DiWVJIteOD9ri
# 3  spotify:track:6jTZGXH1cOQM3jhh07ZE1y
# 4  spotify:track:1ePn7ToIaezbA4tlmj4Kgh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0e1mUAXE8jSG...
# 1  https://api.spotify.com/v1/tracks/7zQFM7bHcyMh...
# 2  https://api.spotify.com/v1/tracks/2Qu65QrO1DiW...
# 3  https://api.spotify.com/v1/tracks/6jTZGXH1cOQM...
# 4  https://api.spotify.com/v1/tracks/1ePn7ToIaezb...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0e1m...        65053
# 1  https://api.spotify.com/v1/audio-analysis/7zQF...       160827
# 2  https://api.spotify.com/v1/audio-analysis/2Qu6...        71160
# 3  https://api.spotify.com/v1/audio-analysis/6jTZ...       128213
# 4  https://api.spotify.com/v1/audio-analysis/1ePn...        71040
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 57 columns]

# %%
# Fix track.artists so we only see the first artist
data['track.artists'] = [data['track.artists'][x][0]['name'] for x in range(len(data['track.artists']))]

# %%
data.loc[0]
# Out:
# added_at                                                           2023-09-10T11:18:03Z
# is_local                                                                          False
# primary_color                                                                      None
# added_by.external_urls.spotify                           https://open.spotify.com/user/
# added_by.href                                         https://api.spotify.com/v1/users/
# added_by.id
# added_by.type                                                                      user
# added_by.uri                                                              spotify:user:
# track.album.album_type                                                            album
# track.album.artists                   [{'external_urls': {'spotify': 'https://open.s...
# track.album.available_markets         [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# track.album.external_urls.spotify     https://open.spotify.com/album/0MRTAsSv2VDaLyM...
# track.album.href                      https://api.spotify.com/v1/albums/0MRTAsSv2VDa...
# track.album.id                                                   0MRTAsSv2VDaLyMiNLkyQN
# track.album.images                    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# track.album.name                                                    More Singable Songs
# track.album.release_date                                                           1977
# track.album.release_date_precision                                                 year
# track.album.total_tracks                                                             16
# track.album.type                                                                  album
# track.album.uri                                    spotify:album:0MRTAsSv2VDaLyMiNLkyQN
# track.artists                                                                     Raffi
# track.available_markets               [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# track.disc_number                                                                     1
# track.duration_ms                                                                 65053
# track.episode                                                                     False
# track.explicit                                                                    False
# track.external_ids.isrc                                                    USRO29605213
# track.external_urls.spotify           https://open.spotify.com/track/0e1mUAXE8jSG9Ex...
# track.href                            https://api.spotify.com/v1/tracks/0e1mUAXE8jSG...
# track.id                                                         0e1mUAXE8jSG9ExAS4AWU7
# track.is_local                                                                    False
# track.name                                                         Shake My Sillies Out
# track.popularity                                                                     63
# track.preview_url                                                                  None
# track.track                                                                        True
# track.track_number                                                                   13
# track.type                                                                        track
# track.uri                                          spotify:track:0e1mUAXE8jSG9ExAS4AWU7
# video_thumbnail.url                                                                None
# danceability                                                                      0.544
# energy                                                                             0.47
# key                                                                                   2
# loudness                                                                        -14.901
# mode                                                                                  1
# speechiness                                                                       0.236
# acousticness                                                                      0.859
# instrumentalness                                                                    0.0
# liveness                                                                          0.346
# valence                                                                           0.671
# tempo                                                                           185.302
# type                                                                     audio_features
# uri                                                spotify:track:0e1mUAXE8jSG9ExAS4AWU7
# track_href                            https://api.spotify.com/v1/tracks/0e1mUAXE8jSG...
# analysis_url                          https://api.spotify.com/v1/audio-analysis/0e1m...
# duration_ms                                                                       65053
# time_signature                                                                        4
# Name: 0, dtype: object

# %%
data.to_csv(f"data/{playlist_name}.csv")
