# %%
# Thank you to https://stmorse.github.io/journal/spotify-api.html for getting started
import numpy as np
import pandas as pd # csv and dataframes
import requests # Spotify API
import config_secrets # Retrieve my secrets from this file

# Secrets from developer.spotify.com account
# You would have to change this
CLIENT_ID = config_secrets.CLIENT_ID
CLIENT_SECRET = config_secrets.CLIENT_SECRET

# How to get a token
AUTH_URL = 'https://accounts.spotify.com/api/token'

# Where to send spotify GET requests
BASE_URL = 'https://api.spotify.com/v1/'

# %%
# POST to get our access token
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET
})

auth_response_data = auth_response.json()
access_token = auth_response_data['access_token']

# Include this in every GET request to make sure we have access
headers = {'Authorization': f"Bearer {access_token}"}

# %%
### CHANGE THIS ###############
playlist_name = "Taylor Swift"
playlist_id = "4eHM58IENfJBe3XL9OIvjV"
###############################

next_request = f"{BASE_URL}playlists/{playlist_id}/tracks"
chunks = []
while next_request != None:
    r_playlist = requests.get(next_request, headers=headers)
    chunks.append(pd.json_normalize(r_playlist.json()['items']))
    # This will contain a valid request if there are more tracks
    # or None if we have all the tracks in the playlist
    next_request = r_playlist.json()['next']

df_playlist = pd.concat(chunks)
df_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 53
# Data columns (total 40 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   added_at                            254 non-null    object
#  1   is_local                            254 non-null    bool
#  2   primary_color                       0 non-null      object
#  3   added_by.external_urls.spotify      254 non-null    object
#  4   added_by.href                       254 non-null    object
#  5   added_by.id                         254 non-null    object
#  6   added_by.type                       254 non-null    object
#  7   added_by.uri                        254 non-null    object
#  8   track.album.album_type              254 non-null    object
#  9   track.album.artists                 254 non-null    object
#  10  track.album.available_markets       254 non-null    object
#  11  track.album.external_urls.spotify   254 non-null    object
#  12  track.album.href                    254 non-null    object
#  13  track.album.id                      254 non-null    object
#  14  track.album.images                  254 non-null    object
#  15  track.album.name                    254 non-null    object
#  16  track.album.release_date            254 non-null    object
#  17  track.album.release_date_precision  254 non-null    object
#  18  track.album.total_tracks            254 non-null    int64
#  19  track.album.type                    254 non-null    object
#  20  track.album.uri                     254 non-null    object
#  21  track.artists                       254 non-null    object
#  22  track.available_markets             254 non-null    object
#  23  track.disc_number                   254 non-null    int64
#  24  track.duration_ms                   254 non-null    int64
#  25  track.episode                       254 non-null    bool
#  26  track.explicit                      254 non-null    bool
#  27  track.external_ids.isrc             254 non-null    object
#  28  track.external_urls.spotify         254 non-null    object
#  29  track.href                          254 non-null    object
#  30  track.id                            254 non-null    object
#  31  track.is_local                      254 non-null    bool
#  32  track.name                          254 non-null    object
#  33  track.popularity                    254 non-null    int64
#  34  track.preview_url                   0 non-null      object
#  35  track.track                         254 non-null    bool
#  36  track.track_number                  254 non-null    int64
#  37  track.type                          254 non-null    object
#  38  track.uri                           254 non-null    object
#  39  video_thumbnail.url                 0 non-null      object
# dtypes: bool(5), int64(5), object(30)
# memory usage: 72.7+ KB

# %%
# Get audio features described at the link below (up to 100 songs at a time)
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features
#r_features = requests.get(BASE_URL + 'audio-features?ids=' + ','.join(df_playlist['track.id']), headers=headers)
#df_features = pd.json_normalize(r_features.json()['audio_features'])
#df_features.info()

track_groups = np.array_split(df_playlist['track.id'], len(df_playlist) // 100 + 1)
chunks = []
for group in track_groups:
    r_features = requests.get(BASE_URL + 'audio-features?ids=' + ','.join(group), headers=headers)
    chunks.append(pd.json_normalize(r_features.json()['audio_features']))

df_features = pd.concat(chunks)
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 83
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      254 non-null    float64
#  1   energy            254 non-null    float64
#  2   key               254 non-null    int64
#  3   loudness          254 non-null    float64
#  4   mode              254 non-null    int64
#  5   speechiness       254 non-null    float64
#  6   acousticness      254 non-null    float64
#  7   instrumentalness  254 non-null    float64
#  8   liveness          254 non-null    float64
#  9   valence           254 non-null    float64
#  10  tempo             254 non-null    float64
#  11  type              254 non-null    object
#  12  id                254 non-null    object
#  13  uri               254 non-null    object
#  14  track_href        254 non-null    object
#  15  analysis_url      254 non-null    object
#  16  duration_ms       254 non-null    int64
#  17  time_signature    254 non-null    int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 37.7+ KB

# %%
# Join the original table with the data we got from the Spotify API
data = df_playlist.join(df_features.set_index('id'), on='track.id', how='inner')
data.reset_index(drop=True)
data.info() # Look at those columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 53
# Data columns (total 57 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   added_at                            254 non-null    object
#  1   is_local                            254 non-null    bool
#  2   primary_color                       0 non-null      object
#  3   added_by.external_urls.spotify      254 non-null    object
#  4   added_by.href                       254 non-null    object
#  5   added_by.id                         254 non-null    object
#  6   added_by.type                       254 non-null    object
#  7   added_by.uri                        254 non-null    object
#  8   track.album.album_type              254 non-null    object
#  9   track.album.artists                 254 non-null    object
#  10  track.album.available_markets       254 non-null    object
#  11  track.album.external_urls.spotify   254 non-null    object
#  12  track.album.href                    254 non-null    object
#  13  track.album.id                      254 non-null    object
#  14  track.album.images                  254 non-null    object
#  15  track.album.name                    254 non-null    object
#  16  track.album.release_date            254 non-null    object
#  17  track.album.release_date_precision  254 non-null    object
#  18  track.album.total_tracks            254 non-null    int64
#  19  track.album.type                    254 non-null    object
#  20  track.album.uri                     254 non-null    object
#  21  track.artists                       254 non-null    object
#  22  track.available_markets             254 non-null    object
#  23  track.disc_number                   254 non-null    int64
#  24  track.duration_ms                   254 non-null    int64
#  25  track.episode                       254 non-null    bool
#  26  track.explicit                      254 non-null    bool
#  27  track.external_ids.isrc             254 non-null    object
#  28  track.external_urls.spotify         254 non-null    object
#  29  track.href                          254 non-null    object
#  30  track.id                            254 non-null    object
#  31  track.is_local                      254 non-null    bool
#  32  track.name                          254 non-null    object
#  33  track.popularity                    254 non-null    int64
#  34  track.preview_url                   0 non-null      object
#  35  track.track                         254 non-null    bool
#  36  track.track_number                  254 non-null    int64
#  37  track.type                          254 non-null    object
#  38  track.uri                           254 non-null    object
#  39  video_thumbnail.url                 0 non-null      object
#  40  danceability                        254 non-null    float64
#  41  energy                              254 non-null    float64
#  42  key                                 254 non-null    int64
#  43  loudness                            254 non-null    float64
#  44  mode                                254 non-null    int64
#  45  speechiness                         254 non-null    float64
#  46  acousticness                        254 non-null    float64
#  47  instrumentalness                    254 non-null    float64
#  48  liveness                            254 non-null    float64
#  49  valence                             254 non-null    float64
#  50  tempo                               254 non-null    float64
#  51  type                                254 non-null    object
#  52  uri                                 254 non-null    object
#  53  track_href                          254 non-null    object
#  54  analysis_url                        254 non-null    object
#  55  duration_ms                         254 non-null    int64
#  56  time_signature                      254 non-null    int64
# dtypes: bool(5), float64(9), int64(9), object(34)
# memory usage: 106.4+ KB

# %%
data.head() # Look at the first few rows of data
# Out:
#                added_at  is_local primary_color  \
# 0  2020-08-17T17:52:38Z     False          None
# 1  2020-08-17T17:52:38Z     False          None
# 2  2020-08-17T17:52:38Z     False          None
# 3  2020-08-17T17:52:38Z     False          None
# 4  2020-08-17T17:52:38Z     False          None
#
#                     added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/katiekaminski1115
# 1  https://open.spotify.com/user/katiekaminski1115
# 2  https://open.spotify.com/user/katiekaminski1115
# 3  https://open.spotify.com/user/katiekaminski1115
# 4  https://open.spotify.com/user/katiekaminski1115
#
#                                        added_by.href        added_by.id  \
# 0  https://api.spotify.com/v1/users/katiekaminski...  katiekaminski1115
# 1  https://api.spotify.com/v1/users/katiekaminski...  katiekaminski1115
# 2  https://api.spotify.com/v1/users/katiekaminski...  katiekaminski1115
# 3  https://api.spotify.com/v1/users/katiekaminski...  katiekaminski1115
# 4  https://api.spotify.com/v1/users/katiekaminski...  katiekaminski1115
#
#   added_by.type                    added_by.uri track.album.album_type  \
# 0          user  spotify:user:katiekaminski1115                  album
# 1          user  spotify:user:katiekaminski1115                  album
# 2          user  spotify:user:katiekaminski1115                  album
# 3          user  spotify:user:katiekaminski1115                  album
# 4          user  spotify:user:katiekaminski1115                  album
#
#                                  track.album.artists  ... instrumentalness  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...              0.0
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...              0.0
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...              0.0
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...              0.0
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...              0.0
#
#   liveness valence    tempo            type  \
# 0   0.1210   0.425   76.009  audio_features
# 1   0.0962   0.821  105.586  audio_features
# 2   0.1190   0.289   99.953  audio_features
# 3   0.3200   0.428  115.028  audio_features
# 4   0.1230   0.261  175.558  audio_features
#
#                                     uri  \
# 0  spotify:track:0Om9WAB5RS09L80DyOfTNa
# 1  spotify:track:32mVHdy0bi1XKgr0ajsBlG
# 2  spotify:track:7zMcNqs55Mxer82bvZFkpg
# 3  spotify:track:73OX8GdpOeGzKC6OvGSbsv
# 4  spotify:track:7an1exwMnfYRcdVQm0yDev
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0Om9WAB5RS09...
# 1  https://api.spotify.com/v1/tracks/32mVHdy0bi1X...
# 2  https://api.spotify.com/v1/tracks/7zMcNqs55Mxe...
# 3  https://api.spotify.com/v1/tracks/73OX8GdpOeGz...
# 4  https://api.spotify.com/v1/tracks/7an1exwMnfYR...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0Om9...       232107
# 1  https://api.spotify.com/v1/audio-analysis/32mV...       173067
# 2  https://api.spotify.com/v1/audio-analysis/7zMc...       203040
# 3  https://api.spotify.com/v1/audio-analysis/73OX...       199200
# 4  https://api.spotify.com/v1/audio-analysis/7an1...       239013
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 57 columns]

# %%
data.iloc[210]
# Out:
# added_at                                                           2022-10-21T17:25:36Z
# is_local                                                                          False
# primary_color                                                                      None
# added_by.external_urls.spotify          https://open.spotify.com/user/katiekaminski1115
# added_by.href                         https://api.spotify.com/v1/users/katiekaminski...
# added_by.id                                                           katiekaminski1115
# added_by.type                                                                      user
# added_by.uri                                             spotify:user:katiekaminski1115
# track.album.album_type                                                            album
# track.album.artists                   [{'external_urls': {'spotify': 'https://open.s...
# track.album.available_markets         [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# track.album.external_urls.spotify     https://open.spotify.com/album/3lS1y25WAhcqJDA...
# track.album.href                      https://api.spotify.com/v1/albums/3lS1y25WAhcq...
# track.album.id                                                   3lS1y25WAhcqJDATJK70Mq
# track.album.images                    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# track.album.name                                                Midnights (3am Edition)
# track.album.release_date                                                     2022-10-22
# track.album.release_date_precision                                                  day
# track.album.total_tracks                                                             20
# track.album.type                                                                  album
# track.album.uri                                    spotify:album:3lS1y25WAhcqJDATJK70Mq
# track.artists                         [{'external_urls': {'spotify': 'https://open.s...
# track.available_markets               [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# track.disc_number                                                                     1
# track.duration_ms                                                                225194
# track.episode                                                                     False
# track.explicit                                                                    False
# track.external_ids.isrc                                                    USUG12207557
# track.external_urls.spotify           https://open.spotify.com/track/3QF5RsWzK1lCvf2...
# track.href                            https://api.spotify.com/v1/tracks/3QF5RsWzK1lC...
# track.id                                                         3QF5RsWzK1lCvf2o2cY65P
# track.is_local                                                                    False
# track.name                                                                  Dear Reader
# track.popularity                                                                     71
# track.preview_url                                                                  None
# track.track                                                                        True
# track.track_number                                                                   20
# track.type                                                                        track
# track.uri                                          spotify:track:3QF5RsWzK1lCvf2o2cY65P
# video_thumbnail.url                                                                None
# danceability                                                                      0.562
# energy                                                                            0.388
# key                                                                                   0
# loudness                                                                        -12.088
# mode                                                                                  1
# speechiness                                                                      0.0705
# acousticness                                                                      0.481
# instrumentalness                                                                0.00145
# liveness                                                                          0.117
# valence                                                                           0.159
# tempo                                                                           107.747
# type                                                                     audio_features
# uri                                                spotify:track:3QF5RsWzK1lCvf2o2cY65P
# track_href                            https://api.spotify.com/v1/tracks/3QF5RsWzK1lC...
# analysis_url                          https://api.spotify.com/v1/audio-analysis/3QF5...
# duration_ms                                                                      225194
# time_signature                                                                        4
# Name: 10, dtype: object

# %%
data.to_csv(f"data/{playlist_name}.csv",index=False)
